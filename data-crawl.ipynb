# %%
from google_play_scraper import reviews
from datetime import datetime
import pandas as pd

# %%
result, continuation_token = reviews("kr.epopsoft.word", lang="ko", country="kr")
cnt = 0

while True:
    cnt += 1
    print(f"{cnt}번째 크롤링 중...")
    tlst, continuation_token = reviews("kr.epopsoft.word", lang="ko", country="kr", continuation_token=continuation_token)
    result += tlst
    last = result[-1]["at"]
    
    if cnt == 19:
        break
# Out:
# 1번째 크롤링 중...
# 2번째 크롤링 중...
# 3번째 크롤링 중...
# 4번째 크롤링 중...
# 5번째 크롤링 중...
# 6번째 크롤링 중...
# 7번째 크롤링 중...
# 8번째 크롤링 중...
# 9번째 크롤링 중...
# 10번째 크롤링 중...
# 11번째 크롤링 중...
# 12번째 크롤링 중...
# 13번째 크롤링 중...
# 14번째 크롤링 중...
# 15번째 크롤링 중...
# 16번째 크롤링 중...
# 17번째 크롤링 중...
# 18번째 크롤링 중...
# 19번째 크롤링 중...

# %%
print(f"{len(result)}개가 크롤링됐어요")
print(result[-1]["at"])
print(type(result[-1]["at"]))
# Out:
# 2000개가 크롤링됐어요
# 2024-10-17 23:13:26
# <class 'datetime.datetime'>

# %%
test = result[4]
for k, v in test.items():
    print(f"{k}: {v}")
# Out:
# reviewId: 4435e13a-e5fc-4de5-81bd-d3bba0d7e4c4
# userName: 하재욱
# userImage: https://play-lh.googleusercontent.com/a-/ALV-UjU_KcHdw1FBTZW6vUNcl9Lggx92AHIzFyN6r6wxeZX305v7aDg
# content: 안녕하세요. 현재 갤럭시에서 말해보카를 카카오 계정으로 로그인하여 사용 중이며, 구독을 생각하고 있습니다. 다음 달에 아이폰으로 변경할 예정인데, 만약 갤럭시에서 구독을 하면 기존 구독이 그대로 유지될 수 있는지 궁금합니다. 1. 아이폰에서 같은 카카오 계정으로 로그인하면 구독 혜택을 그대로 사용할 수 있나요? 2. 만약 구독이 유지되지 않는다면, 안드로이드에서 해지 후 iOS에서 다시 구독해야 하나요? 3. 남은 구독 기간을 이전할 수 있는 방법이 있나요? 확인 후 답변 부탁드립니다. 감사합니다!
# score: 5
# thumbsUpCount: 0
# reviewCreatedVersion: 1.2.324
# at: 2025-01-30 16:31:11
# replyContent: None
# repliedAt: None
# appVersion: 1.2.324

# %%
df = pd.DataFrame(result)
df
# Out:
#                                   reviewId                  userName  \
# 0     870ae293-2a03-4e25-abf8-e13f7fd9ccce                       김인수
# 1     103237f7-fe21-4db0-9ef8-681b405ff72c                   은혜갚는호랑이
# 2     d89082ae-5d09-42dc-aeaa-c8fd0e3a63ac                       양미옥
# 3     549ce3a4-9dcc-479a-8b25-f0cdb6dcbdeb                       백연숙
# 4     7644fc70-da64-473d-844a-1b89e8b92b79                       이근이
# ...                                    ...                       ...
# 1995  98be8411-ac05-4f6a-b191-6ce0655ce9f3             calli go (연잎)
# 1996  b7693500-9163-4aed-8290-d96fd216b0c0                       서한민
# 1997  54997792-3275-4cac-99c9-7eaef5926370                       백승현
# 1998  c81a982a-0a8f-4c35-9a35-e32d632baa68                       박현아
# 1999  7577cb97-a5a1-4a85-a147-86a2aa4e7548  jihyuk jang (jangs gogo)
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# 2     https://play-lh.googleusercontent.com/a/ACg8oc...
# 3     https://play-lh.googleusercontent.com/a/ACg8oc...
# 4     https://play-lh.googleusercontent.com/a/ACg8oc...
# ...                                                 ...
# 1995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                 content  score  thumbsUpCount  \
# 0                                                좋네용 ㅎㅎ      5              0
# 1                                                   좋네요      5              0
# 2        왕초보인데 해외여행 때문에 시작했습니다. 초보도 쉽게 따라할수 있도록 되있어 좋아요      5              0
# 3     처음에 괜찮은데 나중에 행사때문에 학생인증하면 7일 무료가 전 필요 없어요. 그래서...      3              0
# 4     영어를 쉽고 재미있게 공부하게 해주는 많지 않은 양으로 틀린단어는 복습으로 발음 비...      5              0
# ...                                                 ...    ...            ...
# 1995  재밌고 접근하기 쉬워서 초보자인데 흥미가 생기네요!!매일 도전해볼 마음이 생겨요!!...      5              8
# 1996                                저의 영어 실력에 딱 좋은거 같아요      5              0
# 1997  모르는 영단어 학습과 더불어 비슷한 뜻이지만 다른 의미를 가진 단어들도 알 수 있어...      5              0
# 1998  이건 내가본것 중에 가장 사용하기쉽고 편리해서 친구아니면공부로하는걸추천해요 아그리고...      5              0
# 1999                                           정말 좋습니다.      5              0
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                 1.2.324 2025-02-01 00:39:53         None       NaT
# 1                 1.2.324 2025-01-31 23:54:03         None       NaT
# 2                 1.2.324 2025-01-31 23:50:07         None       NaT
# 3                 1.2.324 2025-01-31 23:31:23         None       NaT
# 4                 1.2.324 2025-01-31 23:17:04         None       NaT
# ...                   ...                 ...          ...       ...
# 1995              1.2.310 2024-10-18 08:52:24         None       NaT
# 1996              1.2.310 2024-10-18 06:45:56         None       NaT
# 1997              1.2.310 2024-10-18 00:43:18         None       NaT
# 1998              1.2.310 2024-10-17 23:21:08         None       NaT
# 1999                 None 2024-10-17 23:13:26         None       NaT
#
#      appVersion
# 0       1.2.324
# 1       1.2.324
# 2       1.2.324
# 3       1.2.324
# 4       1.2.324
# ...         ...
# 1995    1.2.310
# 1996    1.2.310
# 1997    1.2.310
# 1998    1.2.310
# 1999       None
#
# [2000 rows x 11 columns]

# %%
# 데이터 전처리(버전확인)
#newest_df = df[df["reviewCreatedVersion"] == "1.2.324"]

# 필요한 열만
# newest_df = newest_df[["reviewId", "userName", "content", "score", "thumbsUpCount", "at"]]
df = df[["reviewId", "userName", "content", "score", "thumbsUpCount", "at"]]

# %%
import time
now = str(time.strftime("%y%m%d"))
now
# Out:
# '250202'

# %%
df.to_excel(now+"_review_data.xlsx")
